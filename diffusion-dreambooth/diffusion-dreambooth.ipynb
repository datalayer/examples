# %% [markdown]
# # Fune tuning stable diffusion model with DreamBooth technique
#
# It is a technique that can update the whole weights of diffusion model with using only a couple of images. These images can teach the model an object or a style.

# %% [markdown]
# ## Setup
#
# Check the memory size, it should be at least 12GB for this notebook

# %%
# GPU check
# !nvidia-smi
# Out:
# Wed Jun 26 12:40:27 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100S-PCIE-32GB          On  |   00000000:00:05.0 Off |                    0 |
# | N/A   42C    P0             27W /  250W |       0MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Install Diffusers library

# %%
# !git clone https://github.com/huggingface/diffusers
# %cd diffusers
# !pip install .

# %% [markdown]
# ## Install DreamBooth method requirements

# %%
# %cd examples/dreambooth
# !pip install -r requirements.txt
# !pip install bitsandbytes
# !pip install transformers ftfy accelerate

# %%
# !pip install --upgrade huggingface-hub

# %% [markdown]
# ## Datasets

# %% [markdown]
# Create a folder for Custom Datasets.
# This folder is for preparing the **instance** and **class** images.

# %%
import os

if os.path.exists("custom_dataset"):
    print("Removing existing custom_dataset folder")
    # !rm -rf custom_dataset

print("Creating new custom_dataset folder")
# !mkdir custom_dataset
# !mkdir custom_dataset/instance_images

print('Custom Dataset folder is created: custom_dataset')
# Out:
# Creating new custom_dataset folder
# Custom Dataset folder is created: custom_dataset

# %% [markdown]
# ### Utils for dataset preprocessing
#
# - Resize and crop function
# - Function to show images in a one row

# %%
from PIL import Image
import os
import IPython.display as display
import matplotlib.pyplot as plt

def resize_and_crop_images(folder_path, target_size=512):
    """
    Resize the images in a folder to have a smaller edge of the specified target size and display them.

    Parameters:
    - folder_path (str): Path to the folder containing the images.
    - target_size (int): Desired size for the smaller edge (default is 512).
    """
    # Iterate through all files in the folder
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        # Check if the file is an image
        if os.path.isfile(file_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
            # Open the image
            image = Image.open(file_path)

            # Get the original width and height
            width, height = image.size

            # Calculate the new size while maintaining the aspect ratio
            if width <= height:
                new_width = target_size
                new_height = int(height * (target_size / width))
            else:
                new_width = int(width * (target_size / height))
                new_height = target_size

            # Resize the image
            resized_image = image.resize((new_width, new_height))

            left = (new_width - target_size) // 2
            top = (new_height - target_size) // 2
            right = (new_width + target_size) // 2
            bottom = (new_height + target_size) // 2

            # Perform the center crop
            cropped_image = resized_image.crop((left, top, right, bottom))
            cropped_image.save(file_path)

def show_images_in_one_row(folder_path, target_size=256):
    images = []

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
            img = Image.open(file_path)
            img = img.resize((target_size, int(target_size * img.size[1] / img.size[0])))
            images.append(img)

    # Display images in one row
    fig, axes = plt.subplots(1, len(images), figsize=(len(images) * 3, 3))
    for ax, img in zip(axes, images):
        ax.imshow(img)
        ax.axis('off')
    plt.show()

# %% [markdown]
# ### Instance images

# %%
import requests
import os
from tqdm import tqdm  

# GitHub repository URL and path to the folder
base_url = 'https://raw.githubusercontent.com/google/dreambooth/main/dataset/dog2/'

# Local destination directory
destination_dir = 'custom_dataset/instance_images/'

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Fetching file list from GitHub
response = requests.get('https://api.github.com/repos/google/dreambooth/contents/dataset/dog2')
file_list = response.json()

# Download each file in the list
for file in tqdm(file_list):
    if file['type'] == 'file':
        file_url = base_url + file['name']
        file_destination = os.path.join(destination_dir, file['name'])
        response = requests.get(file_url)
        with open(file_destination, 'wb') as f:
            f.write(response.content)

print(f'Downloaded images to {destination_dir}')
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 24.79it/s]
# Downloaded images to custom_dataset/instance_images/

# %%
# Resize instance images to 512x512 for diffusion model

folder_path = 'custom_dataset/instance_images' #@param {type:"string"}
resize_and_crop_images(folder_path)

show_images_in_one_row(folder_path)

# %% [markdown]
# ## Fine-tuning Stable Diffusion with DreamBooth method

# %%
# Create an output folder for saving the results and checkpoints

if os.path.exists("outputs"):
    print("Removing existing outputs folder")
    # !rm -rf outputs

print("Creating new outputs folder")
# !mkdir outputs

print('Output folder is created: outputs')
# Out:
# Creating new outputs folder
# Output folder is created: outputs

# %%
# !python train_dreambooth.py --pretrained_model_name_or_path 'runwayml/stable-diffusion-v1-5' \
--revision "fp16" \
--instance_data_dir 'custom_dataset/instance_images' \
--class_data_dir 'custom_dataset/class_images' \
--instance_prompt 'A photo of a zhr dog' \
--class_prompt 'A photo of a dog' \
--with_prior_preservation \
--prior_loss_weight 1.0 \
--num_class_images 10 \
--output_dir 'outputs' \
--resolution 512 \
--train_text_encoder \
--train_batch_size 2 \
--sample_batch_size 2 \
--max_train_steps 400 \
--checkpointing_steps 200 \
--gradient_accumulation_steps 1 \
--gradient_checkpointing \
--learning_rate 1e-6 \
--lr_scheduler 'constant' \
--lr_warmup_steps=0 \
--use_8bit_adam \
--validation_prompt 'A photo of a zhr dog' \
--num_validation_images 4 \
--mixed_precision="fp16" \
--set_grads_to_none
# Out:
# /opt/conda/lib/python3.11/site-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /opt/conda/lib/python3.11/site-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)
# 06/26/2024 12:42:01 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# /opt/conda/lib/python3.11/site-packages/diffusers/pipelines/pipeline_loading_utils.py:219: FutureWarning: You are loading the variant fp16 from runwayml/stable-diffusion-v1-5 via `revision='fp16'` even though you can load it via `variant=`fp16`. Loading model variants via `revision='fp16'` is deprecated and will be removed in diffusers v1. Please use `variant='fp16'` instead.
#   warnings.warn(
# unet/diffusion_pytorch_model.safetensors not found
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
# Loading pipeline components...:   0%|                     | 0/6 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...:  33%|████▎        | 2/6 [00:00<00:00, 19.27it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
# An error occurred while trying to fetch /home/jovyan/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/ded79e214aa69e42c24d3f5ac14b76d568679cc2/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /home/jovyan/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/ded79e214aa69e42c24d3f5ac14b76d568679cc2/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# {'num_class_embeds', 'attention_type', 'resnet_skip_time_act', 'addition_time_embed_dim', 'time_embedding_type', 'projection_class_embeddings_input_dim', 'cross_attention_norm', 'use_linear_projection', 'only_cross_attention', 'num_attention_heads', 'conv_out_kernel', 'upcast_attention', 'conv_in_kernel', 'mid_block_only_cross_attention', 'timestep_post_act', 'time_embedding_dim', 'addition_embed_type_num_heads', 'dual_cross_attention', 'reverse_transformer_layers_per_block', 'addition_embed_type', 'dropout', 'resnet_time_scale_shift', 'mid_block_type', 'resnet_out_scale_factor', 'class_embeddings_concat', 'class_embed_type', 'time_embedding_act_fn', 'time_cond_proj_dim', 'transformer_layers_per_block', 'encoder_hid_dim', 'encoder_hid_dim_type'} was not found in config. Values will be initialized to default values.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...:  67%|████████▋    | 4/6 [00:03<00:01,  1.12it/s]An error occurred while trying to fetch /home/jovyan/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/ded79e214aa69e42c24d3f5ac14b76d568679cc2/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /home/jovyan/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/ded79e214aa69e42c24d3f5ac14b76d568679cc2/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# {'force_upcast', 'use_post_quant_conv', 'scaling_factor', 'latents_mean', 'use_quant_conv', 'latents_std', 'shift_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...:  83%|██████████▊  | 5/6 [00:03<00:00,  1.42it/s]/opt/conda/lib/python3.11/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100%|█████████████| 6/6 [00:03<00:00,  1.80it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 06/26/2024 12:42:05 - INFO - __main__ - Number of class images to sample: 10.
# Generating class images: 100%|████████████████████| 5/5 [00:24<00:00,  5.00s/it]
# /opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'thresholding', 'prediction_type', 'variance_type', 'clip_sample_range', 'dynamic_thresholding_ratio', 'sample_max_value', 'rescale_betas_zero_snr', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# /opt/conda/lib/python3.11/site-packages/diffusers/utils/hub_utils.py:340: FutureWarning: You are loading the variant fp16 from runwayml/stable-diffusion-v1-5 via `revision='fp16'`. This behavior is deprecated and will be removed in diffusers v1. One should use `variant='fp16'` instead. However, it appears that runwayml/stable-diffusion-v1-5 currently does not have a diffusion_pytorch_model.fp16.safetensors file in the 'main' branch of runwayml/stable-diffusion-v1-5.
#  The Diffusers team and community would be very grateful if you could open an issue: https://github.com/huggingface/diffusers/issues/new with the title 'runwayml/stable-diffusion-v1-5 is missing diffusion_pytorch_model.fp16.safetensors' so that the correct variant file can be added.
#   warnings.warn(
# An error occurred while trying to fetch runwayml/stable-diffusion-v1-5: runwayml/stable-diffusion-v1-5 does not appear to have a file named diffusion_pytorch_model.safetensors.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# /opt/conda/lib/python3.11/site-packages/diffusers/utils/hub_utils.py:340: FutureWarning: You are loading the variant fp16 from runwayml/stable-diffusion-v1-5 via `revision='fp16'`. This behavior is deprecated and will be removed in diffusers v1. One should use `variant='fp16'` instead. However, it appears that runwayml/stable-diffusion-v1-5 currently does not have a diffusion_pytorch_model.fp16.bin file in the 'main' branch of runwayml/stable-diffusion-v1-5.
#  The Diffusers team and community would be very grateful if you could open an issue: https://github.com/huggingface/diffusers/issues/new with the title 'runwayml/stable-diffusion-v1-5 is missing diffusion_pytorch_model.fp16.bin' so that the correct variant file can be added.
#   warnings.warn(
# {'force_upcast', 'use_post_quant_conv', 'scaling_factor', 'latents_mean', 'use_quant_conv', 'latents_std', 'shift_factor'} was not found in config. Values will be initialized to default values.
# An error occurred while trying to fetch runwayml/stable-diffusion-v1-5: runwayml/stable-diffusion-v1-5 does not appear to have a file named diffusion_pytorch_model.safetensors.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# {'num_class_embeds', 'attention_type', 'resnet_skip_time_act', 'addition_time_embed_dim', 'time_embedding_type', 'projection_class_embeddings_input_dim', 'cross_attention_norm', 'use_linear_projection', 'only_cross_attention', 'num_attention_heads', 'conv_out_kernel', 'upcast_attention', 'conv_in_kernel', 'mid_block_only_cross_attention', 'timestep_post_act', 'time_embedding_dim', 'addition_embed_type_num_heads', 'dual_cross_attention', 'reverse_transformer_layers_per_block', 'addition_embed_type', 'dropout', 'resnet_time_scale_shift', 'mid_block_type', 'resnet_out_scale_factor', 'class_embeddings_concat', 'class_embed_type', 'time_embedding_act_fn', 'time_cond_proj_dim', 'transformer_layers_per_block', 'encoder_hid_dim', 'encoder_hid_dim_type'} was not found in config. Values will be initialized to default values.
# 06/26/2024 12:43:01 - INFO - __main__ - ***** Running training *****
# 06/26/2024 12:43:01 - INFO - __main__ -   Num examples = 10
# 06/26/2024 12:43:01 - INFO - __main__ -   Num batches each epoch = 5
# 06/26/2024 12:43:01 - INFO - __main__ -   Num Epochs = 80
# 06/26/2024 12:43:01 - INFO - __main__ -   Instantaneous batch size per device = 2
# 06/26/2024 12:43:01 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 2
# 06/26/2024 12:43:01 - INFO - __main__ -   Gradient Accumulation steps = 1
# 06/26/2024 12:43:01 - INFO - __main__ -   Total optimization steps = 400
# Steps:   0%|                                            | 0/400 [00:00<?, ?it/s]/opt/conda/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# Steps:  25%|███▎         | 100/400 [01:33<03:59,  1.25it/s, loss=0.548, lr=1e-6]06/26/2024 12:44:35 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A photo of a zhr dog.
# safety_checker/model.safetensors not found
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:00<00:00,  7.92it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00,  9.23it/s]
# {'euler_at_final', 'timestep_spacing', 'lambda_min_clipped', 'lower_order_final', 'algorithm_type', 'prediction_type', 'use_lu_lambdas', 'variance_type', 'solver_order', 'dynamic_thresholding_ratio', 'sample_max_value', 'solver_type', 'use_karras_sigmas', 'rescale_betas_zero_snr', 'final_sigmas_type', 'thresholding'} was not found in config. Values will be initialized to default values.
# /opt/conda/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# Steps:  50%|██████▌      | 200/400 [03:15<03:05,  1.08it/s, loss=0.052, lr=1e-6]06/26/2024 12:46:17 - INFO - accelerate.accelerator - Saving current state to outputs/checkpoint-200
# Configuration saved in outputs/checkpoint-200/unet/config.json
# Model weights saved in outputs/checkpoint-200/unet/diffusion_pytorch_model.safetensors
# 06/26/2024 12:46:26 - INFO - accelerate.checkpointing - Optimizer state saved in outputs/checkpoint-200/optimizer.bin
# 06/26/2024 12:46:26 - INFO - accelerate.checkpointing - Scheduler state saved in outputs/checkpoint-200/scheduler.bin
# 06/26/2024 12:46:26 - INFO - accelerate.checkpointing - Gradient scaler state saved in outputs/checkpoint-200/scaler.pt
# 06/26/2024 12:46:26 - INFO - accelerate.checkpointing - Random states saved in outputs/checkpoint-200/random_states_0.pkl
# 06/26/2024 12:46:26 - INFO - __main__ - Saved state to outputs/checkpoint-200
# 06/26/2024 12:46:26 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A photo of a zhr dog.
# safety_checker/model.safetensors not found
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:00<00:00, 10.35it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 12.06it/s]
# {'euler_at_final', 'timestep_spacing', 'lambda_min_clipped', 'lower_order_final', 'algorithm_type', 'prediction_type', 'use_lu_lambdas', 'variance_type', 'solver_order', 'dynamic_thresholding_ratio', 'sample_max_value', 'solver_type', 'use_karras_sigmas', 'rescale_betas_zero_snr', 'final_sigmas_type', 'thresholding'} was not found in config. Values will be initialized to default values.
# Steps:  75%|█████████▊   | 300/400 [05:09<01:34,  1.06it/s, loss=0.483, lr=1e-6]06/26/2024 12:48:11 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A photo of a zhr dog.
# safety_checker/model.safetensors not found
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:00<00:00, 10.47it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00, 12.20it/s]
# {'euler_at_final', 'timestep_spacing', 'lambda_min_clipped', 'lower_order_final', 'algorithm_type', 'prediction_type', 'use_lu_lambdas', 'variance_type', 'solver_order', 'dynamic_thresholding_ratio', 'sample_max_value', 'solver_type', 'use_karras_sigmas', 'rescale_betas_zero_snr', 'final_sigmas_type', 'thresholding'} was not found in config. Values will be initialized to default values.
# Steps: 100%|█████████████| 400/400 [06:56<00:00,  1.17it/s, loss=0.231, lr=1e-6]06/26/2024 12:49:58 - INFO - accelerate.accelerator - Saving current state to outputs/checkpoint-400
# Configuration saved in outputs/checkpoint-400/unet/config.json
# Model weights saved in outputs/checkpoint-400/unet/diffusion_pytorch_model.safetensors
# 06/26/2024 12:50:09 - INFO - accelerate.checkpointing - Optimizer state saved in outputs/checkpoint-400/optimizer.bin
# 06/26/2024 12:50:09 - INFO - accelerate.checkpointing - Scheduler state saved in outputs/checkpoint-400/scheduler.bin
# 06/26/2024 12:50:09 - INFO - accelerate.checkpointing - Gradient scaler state saved in outputs/checkpoint-400/scaler.pt
# 06/26/2024 12:50:09 - INFO - accelerate.checkpointing - Random states saved in outputs/checkpoint-400/random_states_0.pkl
# 06/26/2024 12:50:09 - INFO - __main__ - Saved state to outputs/checkpoint-400
# 06/26/2024 12:50:09 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A photo of a zhr dog.
# safety_checker/model.safetensors not found
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:00<00:00,  8.36it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00,  9.75it/s]
# {'euler_at_final', 'timestep_spacing', 'lambda_min_clipped', 'lower_order_final', 'algorithm_type', 'prediction_type', 'use_lu_lambdas', 'variance_type', 'solver_order', 'dynamic_thresholding_ratio', 'sample_max_value', 'solver_type', 'use_karras_sigmas', 'rescale_betas_zero_snr', 'final_sigmas_type', 'thresholding'} was not found in config. Values will be initialized to default values.
# Steps: 100%|██████████████| 400/400 [07:16<00:00,  1.17it/s, loss=0.16, lr=1e-6]vae/diffusion_pytorch_model.safetensors not found
# {'requires_safety_checker', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:00<00:00, 19.42it/s]An error occurred while trying to fetch /home/jovyan/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/ded79e214aa69e42c24d3f5ac14b76d568679cc2/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /home/jovyan/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/ded79e214aa69e42c24d3f5ac14b76d568679cc2/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# {'force_upcast', 'use_post_quant_conv', 'scaling_factor', 'latents_mean', 'use_quant_conv', 'latents_std', 'shift_factor'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  71%|█████████▎   | 5/7 [00:01<00:00,  3.09it/s]`text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:06<00:01,  1.60s/it]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:06<00:00,  1.00it/s]
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Configuration saved in outputs/vae/config.json
# Model weights saved in outputs/vae/diffusion_pytorch_model.safetensors
# Configuration saved in outputs/unet/config.json
# Model weights saved in outputs/unet/diffusion_pytorch_model.safetensors
# Configuration saved in outputs/scheduler/scheduler_config.json
# Configuration saved in outputs/model_index.json
# Steps: 100%|██████████████| 400/400 [07:32<00:00,  1.13s/it, loss=0.16, lr=1e-6]

# %% [markdown]
# ## Inference using finetuned model

# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained("outputs", torch_dtype=torch.float16, use_safetensors=True).to("cuda")
image = pipeline("A photo of zhr dog in a bucket", num_inference_steps=50, guidance_scale=7.5).images[0]
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(image)
