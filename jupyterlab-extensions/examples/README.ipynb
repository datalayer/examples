# %% [markdown]
# ![Screenshot 2021-01-09 at 13.35.46.png](attachment:13862473-c4b4-4b92-9741-7ebd93dd63bc.png)

# %% [markdown]
# # You should have a `run all cell` button.
#
# ![run-all.png](attachment:5ca2b08e-6438-4a02-b26b-2a0985fc2563.png)
